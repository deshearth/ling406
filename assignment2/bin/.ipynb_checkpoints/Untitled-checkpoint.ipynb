# %%
'''
These are functions for letter bigram language identification
some details: 
    space and punctuations are preserved when training the model.
'''
import sys
import os
import numpy as np
import codecs
import collections
import pandas as pd
import itertools

# %%
def get_data():
    '''get the preprocessed training data and testing data and store 
    them in the dictionary'''
    workdir = get_workdir() 
    os.path.join = join_path
    data_path = path_join(workdir, 'database')
    data = {}
    data['test'] = readtxt(os.path.join(data_path,'LangId.test'))
    data['train'] = {}
    data['train']['English'] = preprocess(readtxt(os.path.join(data_path,'LangId.train.English')))
    data['train']['French'] = preprocess(readtxt(os.path.join(data_path,'LangId.train.French')))
    data['train']['Italian'] = preprocess(readtxt(os.path.join(data_path,'LangId.train.Italian')))
    return data

def get_workdir():
    bin_path = os.getcwd()
    return os.path.dirname(bin_path)

# %%
def readtxt(path):
    f = codecs.open(path, encoding='latin-1', mode='r')
    data = [(u'≤'+line).replace(u'\n', u'≥') for line in f.readlines()]
    f.close()
    return data

def preprocess(sentences):
    #sentences is a list containing multiple string
    s = np.array(list(''.join(sentences)))
    ss_ = bicharconc(s)
    return {'s': s, 'ss_': ss_} 

def bicharconc(s):
    #s_ is the shifted array of s by one unit
    s_ = np.append(s[1:], s[0])
    #element wise addition of two array, get bigram letter array now
    ss_ = np.core.defchararray.add(s, s_)
    #since the combintation '≥≤' is useless
    return np.delete(ss_, np.where(ss_==u'≥≤'))

# %%
def count(train_data):
    """get the model.
    since every element cc_ in ss_, c appears first, then c_,
    P(c_|c) = P(cc_) / P(c) = #(cc_) / #(c)
    """
    model = pd.DataFrame()
    sskeys = pd.DataFrame(data['train']).loc['ss_',:].values
    sskeys =  list(set(itertools.chain(*map(list, sskeys))))
    for dkey in train_data.keys():
        s, ss_ = train_data[dkey]['s'], train_data[dkey]['ss_']
        s_count, ss_count = map(collections.Counter, [s, ss_])
        for sskey in sskeys: 
            model.loc[sskey, dkey] = smooth(ss_count[sskey], s_count[sskey[0]], len(s_count.keys()))
    return model

def smooth(joint, marg, n_letter):
    'smooth function'
    #joint represents joint prob, marg represents marginal prob
    return laplace(joint, marg, n_letter)

def laplace(joint, marg, n_letter):
    return float(joint+1) / (marg+n_letter)

# %%
def predict(test_data, model):
    predicted_values = []
    for i in xrange(len(test_data)):
        ss_ = bicharconc(list(test_data[i]))     
        logp_sum = np.zeros(3,)
        for bichar in ss_:
            if bichar in model.index.values:
                logp_sum += np.log(model.loc[bichar, :].values)       
        predicted_values.append(model.columns.values[logp_sum.argmax()])
    return np.array(predicted_values)   
                

def evaluate(predicted_values):
    data_path = get_datapath()
    groundtruth_values = np.loadtxt(os.path.join(data_path, 'LangId.sol'), dtype='S', delimiter=' ', usecols=[-1])
    return (groundtruth_values == predicted_values).sum() / float(groundtruth_values.size)

# %%
def write_solution(predicted_values):
    idx = np.arange(predicted_values.size)
    out = np.array(zip(idx, predicted_values))
    workdir = get_workdir()
    out_path = os.path.join(workdir, 'output', 'LangId.sol')
    np.savetxt(out_path, out, fmt='%s', delimiter=' ')
    return out

# %%
sen = u"Signora Presidente , vorrei sapere perché questo Parlamento non rispetta le norme in materia di salute e sicurezza che esso"

# %%
sen
# Out:
# u'Signora Presidente , vorrei sapere perch\xe9 questo Parlamento non rispetta le norme in materia di salute e sicurezza che esso'

# %%
sen.split(' ')
# Out:
# [u'Signora',
#  u'Presidente',
#  u',',
#  u'vorrei',
#  u'sapere',
#  u'perch\xe9',
#  u'questo',
#  u'Parlamento',
#  u'non',
#  u'rispetta',
#  u'le',
#  u'norme',
#  u'in',
#  u'materia',
#  u'di',
#  u'salute',
#  u'e',
#  u'sicurezza',
#  u'che',
#  u'esso']

# %%
workdir = get_workdir()
path = os.path.join(workdir, 'database', 'LangId.train.English')
f = codecs.open(path, encoding='latin-1', mode='r')
s = [[u'≤']+line.strip().split(' ')+[u'≥'] for line in f.readlines()]
f.close()

# %%
a = np.array(list(itertools.chain(*s)))
a
# Out:
# array([u'\u2264', u'Approval', u'of', ..., u')', u'.', u'\u2265'],
#       dtype='<U18')

# %%
t = a
t_ = np.append(t[1:], t[0])
t_
# Out:
# array([u'Approval', u'of', u'the', ..., u'.', u'\u2265', u'\u2264'],
#       dtype='<U18')

# %%
ss_ = reduce(np.core.defchararray.add, [t, u' ', t_])

# %%
np.where(ss_==u'≥ ≤')
# Out:
# (array([    9,    21,    28, ..., 88829, 88840, 88852]),)

# %%
# %load wordLangId.py
'''
Author: Yifeng Chu (ychu26)

These are functions for word bigram language identification
some details: 
    space and punctuations are preserved when training the model.
'''
import os
import numpy as np
import codecs
import collections
import pandas as pd
import itertools

def get_data():
    '''get the preprocessed training data and testing data and store 
    them in the dictionary'''
    workdir = get_workdir()
    join_path = os.path.join
    data_path = join_path(workdir, 'database')
    testin_path = join_path(workdir, 'input') 
    data = {}
    data['test'] = readtxt(join_path(testin_path,'LangId.test'), 'test')
    data['train'] = {}
    data['train']['English'] = preprocess(readtxt(join_path(data_path,'LangId.train.English')))
    data['train']['French'] = preprocess(readtxt(join_path(data_path,'LangId.train.French')))
    data['train']['Italian'] = preprocess(readtxt(join_path(data_path,'LangId.train.Italian')))
    return data

def get_workdir():
    bin_path = os.getcwd()
    return  os.path.dirname(bin_path)

def readtxt(path, *args):
    f = codecs.open(path, encoding='latin-1', mode='r')
    #'â¤â¥' are usd as start and end symbol for every sentence
    data = [[u'â¤'] + line.strip().split(' ') + [u'â¥'] for line in f.readlines()]
    f.close()
    print not args
    return data if args else data[:100]

def preprocess(sentences):
    w = np.array(list(itertools.chain(*sentences)))
    ww_ = biwordconc(w)
    return {'w': w, 'ww_': ww_}

def biwordconc(w):
    w_ = np.append(w[1:], w[0])
    # in order to separate two words, add a space between them
    ww_ = reduce(np.core.defchararray.add, [w, u' ', w_])
    return np.delete(ww_, np.where(ww_==u'â¥ â¤'))
    
def train(train_data):
    """get the model.
    since every element vv_ in ww_, v appears first, then v_,
    P(v_|v) = P(vv_) / P(v) = #(vv_) / #(v)
    """
    model = pd.DataFrame()
    #fetch all bichars and remove the redundancy
    wwkeys = pd.DataFrame(train_data).loc['ww_',:].values
    wwkeys =  list(set(itertools.chain(*map(list, wwkeys))))
    priors = []
    #fill the table with probs
    for dkey in train_data.keys():
        w, ww_ = train_data[dkey]['w'], train_data[dkey]['ww_']
        w_cont, ww_cont = map(collections.Counter, [w, ww_])
        #optimization 
        
        for wwkey in wwkeys: 
            model.loc[wwkey, dkey] = smooth(ww_cont[wwkey], w_cont[wwkey[0]], len(w_cont.keys()))
            if wwkeys.index(wwkey) % 10000 == 0:
                print "every 10000 period!!"
        
        print dkey, 'finished!'    
    return model

def smooth(joint, marg, n_word):
    'smooth function'
    #joint represents joint prob, marg represents marginal prob
    return laplace(joint, marg, n_word)

def laplace(joint, marg, n_word):
    return float(joint+1) / (marg+n_word)

def predict(test_data, model, priors):
    'predict the language class using trained model'
    predicted_values = []
    for i in xrange(len(test_data)):
        #same technique for preprocessing the training data, concat the neighbor chars
        ww_ = biwordconc(test_data[i])   
        #to avoid the underflow, use log of prob
        logp_sum = np.zeros(3,)
        for biword in ww_:
            if biword in model.index.values:
                logp_sum += np.log(model.loc[biword, :].values)
        predicted_values.append(model.columns.values[logp_sum.argmax()])

    return np.array(predicted_values)

# %%
data = get_data()
# Out:
# False
# True
# True
# True

# %%
data['train']['English']['ww_'].size
# Out:
# 2440

# %%
model = train(data['train'])
# Out:
# every 10000 period!!
# Italian finished!
# every 10000 period!!
# French finished!
# every 10000 period!!
# English finished!

# %%
# Out:
# array([ 0.03388682,  0.03328895,  0.03937008])

# %%
u'â¤' in data['train']['English']['w']
# Out:
# True

# %%
predicted_values = predict(data['test'], model, priors)

# %%
predicted_values.size
# Out:
# 300

# %%
model
# Out:
#                          Italian    French   English
# avons conjointement     0.000975  0.002301  0.001253
# in Brussels             0.000985  0.001179  0.002639
# relazione che           0.002004  0.001179  0.001319
# Vicepresidente in       0.002004  0.001179  0.001319
# objectif qui            0.000996  0.002358  0.001319
# contre les              0.001002  0.002345  0.001319
# e soprattutto           0.001919  0.001179  0.001314
# perfectly well          0.001002  0.001179  0.005277
# point -                 0.001002  0.002358  0.001319
# British but             0.001002  0.001179  0.002639
# also draw               0.000975  0.001151  0.002506
# ma qualité              0.001002  0.002353  0.001319
# Commission .            0.001001  0.001178  0.002639
# del pubblico            0.001996  0.001143  0.001319
# lotta contro            0.001947  0.001117  0.001319
# completo ,              0.002004  0.001172  0.001319
# médiateur européen      0.001002  0.010588  0.001319
# â¤ Più                 0.002004  0.001179  0.001319
# votre attention         0.001002  0.002358  0.001319
# preuve la               0.001002  0.002358  0.001319
# la campagne             0.000974  0.002235  0.001319
# commission des          0.001002  0.010551  0.001319
# critiques que           0.001002  0.002345  0.001319
# traitées efficacement   0.001002  0.002350  0.001319
# aspect of               0.000975  0.001151  0.003759
# a Bruxelles             0.002924  0.001151  0.001253
# the maladministration   0.001002  0.001175  0.002639
# presented allegations   0.001002  0.001179  0.002639
# di minori               0.001996  0.001143  0.001319
# Ombudsmen as            0.001002  0.001179  0.002639
# ...                          ...       ...       ...
# 1998 alle               0.002004  0.001179  0.001319
# transferred 71          0.001002  0.001175  0.002639
# sure whether            0.001002  0.001172  0.002639
# troisième fois          0.001002  0.002350  0.001319
# impliquent des          0.000985  0.002358  0.001319
# unica alternativa       0.002004  0.001179  0.001319
# you for                 0.001002  0.001175  0.002639
# result is               0.001002  0.001179  0.002639
# illegally imported      0.000985  0.001179  0.002639
# sette casi              0.002004  0.001172  0.001319
# demande ,               0.000998  0.002286  0.001319
# lettera di              0.001947  0.001117  0.001319
# tempestività e          0.002004  0.001175  0.001319
# would mean              0.001002  0.001179  0.002639
# piacevole soggiorno     0.002004  0.001179  0.001319
# alcuna .                0.001949  0.001151  0.001253
# errore da               0.001919  0.001179  0.001314
# richiamo al             0.003006  0.001179  0.001319
# dichiara espressamente  0.001996  0.001143  0.001319
# leurs droits            0.000974  0.002235  0.001319
# president ,             0.001002  0.001179  0.002639
# the vice                0.001002  0.001175  0.003958
# coordinateur régional   0.001002  0.002345  0.001319
# The Minutes             0.001002  0.001179  0.003958
# organised jointly       0.000996  0.001179  0.002639
# there any               0.001002  0.001175  0.002639
# quantità di             0.002004  0.001179  0.001319
# Capo di                 0.002002  0.001178  0.001319
# et inversé              0.000960  0.002358  0.001314
# une once                0.001002  0.002358  0.001319
#
# [5904 rows x 3 columns]

# %%
accuracy = evaluate(predicted_values)
accuracy
# Out:
# 0.94999999999999996

# %%
wwkeys = pd.DataFrame(data['train']).loc['ww_',:].values

# %%
len(collections.Counter(data['train']['English']['ww_']))
# Out:
# 5119

# %%
wwkeys_ =  list(itertools.chain(*map(list, wwkeys)))

# %%
wwkeys__ = list(set(wwkeys_))

# %%
len(wwkeys__)
len(data['train']['English']['ww_'])
# Out:
# 85873

# %%
wwkeys__
# Out:
# [u'Eurocontrol has',
#  u'tempi rapidi',
#  u'cette position',
#  u'collega ,',
#  u'own level',
#  u'pi\xf9 appropriati',
#  u'citizenship that',
#  u'asking :',
#  u'approach the',
#  u'and environmentally',
#  u'cinquantina di',
#  u'asking ,',
#  u'ethnic tensions',
#  u'in lyrical',
#  u'sono gi\xe0',
#  u'past twenty',
#  u'costatare l',
#  u'changes in',
#  u'de quelques',
#  u'communities from',
#  u'essere condiviso',
#  u'say a',
#  u'faits sur',
#  u'( the',
#  u'and complaints',
#  u'bode well',
#  u'to prevent',
#  u'the Freedom',
#  u'chose doit',
#  u'into toxicity',
#  u'dire con',
#  u'et reconnus',
#  u'called for',
#  u'point 9',
#  u'point 8',
#  u'utilisateurs de',
#  u'strong voice',
#  u'be consistent',
#  u'Between 1986',
#  u'colleghi non',
#  u'will make',
#  u'information sur',
#  u'point -',
#  u'point ,',
#  u'point .',
#  u'tre mesi',
#  u'entail .',
#  u'Unione esistono',
#  u'point d',
#  u'Mr Cossutta',
#  u'of hand',
#  u'ma qualit\xe9',
#  u'semblent v\xe9ritablement',
#  u'minuto si',
#  u'lotta contro',
#  u'accessibile a',
#  u'tables .',
#  u'voler in',
#  u'areas handled',
#  u'directly concern',
#  u'society .',
#  u'harmoniser les',
#  u'society ,',
#  u'mensonges est',
#  u'had better',
#  u'Avoir de',
#  u'penalties to',
#  u'identique ,',
#  u'la campagna',
#  u'la campagne',
#  u'point \xe0',
#  u'executive that',
#  u'immediatamente .',
#  u'italiens --',
#  u'35, l',
#  u'money be',
#  u'critiques que',
#  u'effettuate secondo',
#  u'\xe9l\xe9ments font',
#  u'de d\xe9sagr\xe9ment',
#  u'benches .',
#  u'benches ,',
#  u'une travailleuse',
#  u'money by',
#  u'compiere l',
#  u'where necessary',
#  u'to fear',
#  u'svolgono una',
#  u'subit l',
#  u'accaparent aujourd',
#  u'to resume',
#  u'Il dramma',
#  u'home and',
#  u"for ships'",
#  u'victimisation d',
#  u'defending the',
#  u'et offert',
#  u'relazioni !',
#  u'certa preoccupazione',
#  u'followed up',
#  u'ont s\xe9rieusement',
#  u'e sosteniamo',
#  u'diff\xe9renci\xe9e \xe9mane',
#  u'We support',
#  u'presentato dall',
#  u'1998 to',
#  u'dei Ministri',
#  u'Figi ,',
#  u'per intervenire',
#  u'salvaguardia della',
#  u'Nous jetons',
#  u'Andalucista ,',
#  u'ban decision',
#  u'tragedy of',
#  u'up prices',
#  u'the specifics',
#  u'energy on',
#  u'come ci\xf2',
#  u'- alternative',
#  u'immagini paradisiache',
#  u'membri contro',
#  u'around .',
#  u'ha risposto',
#  u'constitue ,',
#  u'mis en',
#  u'ups .',
#  u'Osservatorio ,',
#  u'confini nazionali',
#  u'nos institutions',
#  u'en soit',
#  u'legame madre',
#  u'signature from',
#  u'anche qualora',
#  u'questo tema',
#  u'any criticisms',
#  u'have financial',
#  u'we ask',
#  u'periferiche il',
#  u'- 103',
#  u'only fair',
#  u'ruolo di',
#  u'esclusivamente dal',
#  u'alert and',
#  u'mean discrimination',
#  u'sont avant',
#  u'restino indifferenti',
#  u'dia l',
#  u'Tuesday and',
#  u'of Article',
#  u'can create',
#  u'for ships',
#  u'lequel nous',
#  u'citoyen perd',
#  u'the recognition',
#  u'r\xe9solution dite',
#  u'situazione storica',
#  u'belief in',
#  u'passe actuellement',
#  u'appropri\xe9 .',
#  u'fiscalit\xe9 ,',
#  u'fiscalit\xe9 .',
#  u'massimi livelli',
#  u'far we',
#  u'buona condotta',
#  u'peu d\xe9valoris\xe9',
#  u'est utilis\xe9',
#  u'16 .',
#  u'del\xe0 et',
#  u'des milles',
#  u'preuve que',
#  u'Islam et',
#  u'faire qu',
#  u'way that',
#  u'eu un',
#  u'\xe2\x89\xa4 Even',
#  u'discriminazioni a',
#  u'the slow',
#  u'son cong\xe9',
#  u'respect et',
#  u'ambientale del',
#  u'report clears',
#  u'non essendo',
#  u'avant toute',
#  u'which needs',
#  u'purposes .',
#  u'topics .',
#  u'purposes ,',
#  u'isolana ,',
#  u'della situazione',
#  u'in Istanbul',
#  u'appelons aussi',
#  u'langue du',
#  u'ottimizzare le',
#  u'\xe9cosyst\xe8me de',
#  u'the position',
#  u'purposes ?',
#  u'altrettanto impegno',
#  u'lui beaucoup',
#  u'of Mr',
#  u'the dispute',
#  u'riguardo esprimo',
#  u'Lors des',
#  u'fanno parte',
#  u'dirais que',
#  u'violation .',
#  u', usually',
#  u'periferiche .',
#  u'perch\xe9 nella',
#  u'airspace with',
#  u'clarified the',
#  u'normal birth',
#  u'Vorremmo sapere',
#  u'films from',
#  u'des hommes',
#  u'Vorremmo anche',
#  u'che nutriamo',
#  u'Austrian Government',
#  u'la Gran',
#  u'we pointed',
#  u', lottano',
#  u'it took',
#  u'foreign component',
#  u'further alienates',
#  u'de celles',
#  u'constitue \xe0',
#  u'mien ,',
#  u'me rallie',
#  u'di convergenza',
#  u'childbirth do',
#  u'of giving',
#  u'caso non',
#  u'must congratulate',
#  u'Transports du',
#  u'le destin',
#  u'hors de',
#  u'\xe8 gi\xe0',
#  u'en carton',
#  u'responsabili un',
#  u'auspicato che',
#  u'cerchia un',
#  u'refer .',
#  u'questa riflessione',
#  u'disturbed relationship',
#  u'attends donc',
#  u'mancato un',
#  u'di stabilimento',
#  u'sviluppare tecnologie',
#  u'aspetti nazionali',
#  u'comprend \xe9galement',
#  u'Thors has',
#  u'regulatory structure',
#  u'transposing the',
#  u'collaborateurs qui',
#  u'notre organisation',
#  u'it agrees',
#  u'congratulate her',
#  u'gli aspetti',
#  u'to extreme',
#  u'chiedo se',
#  u'distance to',
#  u', functional',
#  u'Iraq can',
#  u'checking the',
#  u'une \xe9valuation',
#  u'Lambert et',
#  u'notre part',
#  u'erreurs judiciaires',
#  u'elles mettent',
#  u'des obligations',
#  u'their reports',
#  u'single sky',
#  u'preziose superfici',
#  u'dovr\xe0 definire',
#  u'des appareils',
#  u'ordine dei',
#  u'the advent',
#  u'the congestion',
#  u'le plus',
#  u'a European',
#  u'can tell',
#  u'for US',
#  u'recommendation establishes',
#  u'cr\xe9dibilit\xe9 si',
#  u'promotion de',
#  u'contrebalancer de',
#  u'i tibetani',
#  u'scorso sub\xec',
#  u'sais repr\xe9sentatifs',
#  u'\xeatre pond\xe9r\xe9e',
#  u'Si deve',
#  u'in PVC',
#  u'financ\xe9es et',
#  u'de racisme',
#  u'organizzazioni .',
#  u'corrige ,',
#  u'il passato',
#  u'creazione ,',
#  u'comparabili (',
#  u'incapacit\xe9 des',
#  u'it --',
#  u'taluni Stati',
#  u'transport a\xe9rien',
#  u'witness to',
#  u'in paragraphs',
#  u'parte abbandonato',
#  u'Parlement assumant',
#  u'bien fait',
#  u'definitive .',
#  u'sp\xe9cifiques pour',
#  u'\xe0 critiquer',
#  u'you liberalise',
#  u'di sotto',
#  u'pouvons le',
#  u'rapport direct',
#  u'no more',
#  u'vogliamo un',
#  u'durant cette',
#  u'for when',
#  u'e cristiana',
#  u'qui produisent',
#  u'organizzazioni a',
#  u', disporre',
#  u'to find',
#  u'still are',
#  u'vraiment d',
#  u'wondered whether',
#  u'per cos\xec',
#  u'on working',
#  u'programma valido',
#  u'be allowed',
#  u'fraude depuis',
#  u'la r\xe9flexion',
#  u'Member ,',
#  u'su alcuni',
#  u'has traditionally',
#  u'and concedes',
#  u'invece alla',
#  u'essentielles pour',
#  u'clair que',
#  u'int\xe9gralement par',
#  u'/ Sinistra',
#  u'civilian and',
#  u'remain a',
#  u'comunit\xe0 etnica',
#  u'might succeed',
#  u'distrutto gran',
#  u'linea in',
#  u'operi in',
#  u'femmes des',
#  u'per dei',
#  u'migliore "',
#  u'sur cette',
#  u'Venezuela e',
#  u'who does',
#  u'ignoranza circa',
#  u'voci nel',
#  u'monopoles d',
#  u'alla congestione',
#  u'\xe9galement influenc\xe9',
#  u'- examen',
#  u'is referred',
#  u'these will',
#  u'certaines r\xe9solutions',
#  u'Peijis per',
#  u'Europol and',
#  u'an average',
#  u'En se',
#  u'de cong\xe9',
#  u'prochaine .',
#  u'prochaine ,',
#  u'\xe8 tutto',
#  u', sotto',
#  u'temps pour',
#  u'of Chinese',
#  u'raw material',
#  u'siano assicurate',
#  u'accedere ad',
#  u'souhaitait une',
#  u'Gli oneri',
#  u'la centralisation',
#  u'sede lanciamo',
#  u'abbia abbandonato',
#  u'posso solo',
#  u'nel miglior',
#  u'poursuit .',
#  u'That may',
#  u'impatto ambientale',
#  u'organisation \xe9chapperait',
#  u'direttiva minimalista',
#  u'amnesia when',
#  u'accedere ai',
#  u'celle des',
#  u'public too',
#  u'travail normal',
#  u'achieving this',
#  u'please take',
#  u'forza del',
#  u'giving birth',
#  u's conclusions',
#  u'a\xe9rien unique',
#  u'an overwhelming',
#  u'will actually',
#  u'difficulty of',
#  u'travaux de',
#  u'fallu l',
#  u'concordo con',
#  u'will benefit',
#  u'remplacer la',
#  u'ad autorizzazioni',
#  u'indeed an',
#  u'Carinthia and',
#  u'month after',
#  u'ambigu\xeft\xe9 concernant',
#  u'many aspects',
#  u'le plaisir',
#  u'colpi di',
#  u'motivi voto',
#  u'sia letterale',
#  u'not understand',
#  u'n\xe9gative -',
#  u'The desire',
#  u'produisons .',
#  u'implementing a',
#  u'dimensione alla',
#  u'a 20.000',
#  u'tranquillit\xe0 ,',
#  u'mese di',
#  u'verificatasi al',
#  u'le b\xe2t',
#  u'consumato fra',
#  u'link whatsoever',
#  u'course we',
#  u'punti deboli',
#  u'pretendo un',
#  u'finanziamento dell',
#  u'vogliono anche',
#  u'last attempt',
#  u'si rifiuta',
#  u'potr\xe0 costringere',
#  u'de suffisamment',
#  u'groups but',
#  u'pr\xe9occupations principales',
#  u'cesse plus',
#  u'i quali',
#  u'textes ,',
#  u'a Strasburgo',
#  u'arguments dans',
#  u'les propos',
#  u'far\xe0 un',
#  u'emendamento in',
#  u'Moluques et',
#  u'Ombudsman controls',
#  u'seconda guerra',
#  u'entier \xe9tait',
#  u'\xe8 come',
#  u'increasingly losing',
#  u'skies .',
#  u'chemically -',
#  u'Such a',
#  u'; ieri',
#  u'attuare questo',
#  u'sachions de',
#  u'aux pays',
#  u'to adapt',
#  u', realistiche',
#  u'interest rates',
#  u'\xe2\x89\xa4 Azioni',
#  u'doing well',
#  u'avanza alcune',
#  u'\xe2\x89\xa4 Elle',
#  u'decisions are',
#  u'underline a',
#  u'dockside operations',
#  u'Europe rejected',
#  u'Le transport',
#  u'important observations',
#  u'Wahi. e',
#  u'logique qu',
#  u'degli uomini',
#  u'allo Stato',
#  u'possa dire',
#  u'inexactitudes .',
#  u'de nombreux',
#  u'm\xeame aux',
#  u'the so',
#  u'provisional government',
#  u'selvaggia ,',
#  u'sans fronti\xe8res',
#  u'informations scientifiques',
#  u'of positive',
#  u'a commendable',
#  u'les vacances',
#  u'should right',
#  u'collaborer et',
#  u'related accidents',
#  u'working against',
#  u'depuis de',
#  u'juridique global',
#  u'defects are',
#  u'ottenere ci\xf2',
#  u'model is',
#  u'gli utenti',
#  u'd\xe9truit et',
#  u'employment ,',
#  u'de huit',
#  u'n\xe9gociations devraient',
#  u'congestion and',
#  u'will follow',
#  u'Scotland call',
#  u'devoir grappiller',
#  u'pieno riconoscimento',
#  u'operato la',
#  u'convert their',
#  u'parla di',
#  u'avec d\xe9termination',
#  u'contribution Professor',
#  u'exigeant du',
#  u'regret the',
#  u'they revise',
#  u'coastline and',
#  u'Council Directive',
#  u'di minori',
#  u'be funded',
#  u'west of',
#  u'by poverty',
#  u'certains documents',
#  u'eliminazione della',
#  u'let us',
#  u'second temps',
#  u'realt\xe0 pratica',
#  u'bien puisqu',
#  u'Invitiamo pertanto',
#  u'juillet .',
#  u'that to',
#  u'cospicua serie',
#  u'pubblica acquista',
#  u'du texte',
#  u'amendements de',
#  u'ne hanno',
#  u'promozione delle',
#  u'is easy',
#  u'mai avvenuta',
#  u'soprattutto mi',
#  u'complaint .',
#  u'boiteux "',
#  u'reply by',
#  u'Parlamento illustrano',
#  u'monopoles ,',
#  u'educare .',
#  u'- eux',
#  u'di Mary',
#  u'communications with',
#  u'soutenir la',
#  u'coined by',
#  u'are of',
#  u'soutenir le',
#  u'quindi chiediamo',
#  u'ESF Regulation',
#  u'au niveau',
#  u'important addition',
#  u'have forcibly',
#  u'o discriminata',
#  u'\xeatre exceptionnellement',
#  u'essa potrebbe',
#  u'incitare i',
#  u'encore \xeatre',
#  u'del tratto',
#  u'Our Group',
#  u'of their',
#  u'del momento',
#  u'Action for',
#  u'rielezione il',
#  u'a quello',
#  u'la perte',
#  u'la coltivazione',
#  u'for these',
#  u'a quelle',
#  u'della motivazione',
#  u'firma elettronica',
#  u'a quella',
#  u'Earlier it',
#  u'subsiste un',
#  u'the delegation',
#  u'affaire doivent',
#  u'on men',
#  u'meglio da',
#  u'sens se',
#  u'official reply',
#  u'marzo 2001',
#  u'vari dati',
#  u', lento',
#  u'una definizione',
#  u'Rapport Schierhuber',
#  u'parties en',
#  u'questa battaglia',
#  u'che detto',
#  u'piuttosto pensare',
#  u'a peu',
#  u'intent in',
#  u'programmi dedicati',
#  u'pretesa delle',
#  u'e tecnicamente',
#  u'meglio e',
#  u'sample here',
#  u'the Vice',
#  u'verr\xe0 valutato',
#  u'sp\xe9cialistes des',
#  u'enjoy a',
#  u'il basso',
#  u'corrected to',
#  u'Minister specified',
#  u'jeopardising the',
#  u'that all',
#  u'corporations from',
#  u'valore sociale',
#  u'\xe2\x89\xa4 Virrankoski',
#  u'is shameful',
#  u'mouvement eurosceptique',
#  u'dichiarazioni che',
#  u'considerevole nell',
#  u'sia del',
#  u'aircraft to',
#  u'dans 97',
#  u'd\xe9coule de',
#  u'retard consid\xe9rable',
#  u'the pretext',
#  u'existence et',
#  u'rightly criticised',
#  u's discharge',
#  u'Ombudsman and',
#  u'da chi',
#  u'reversed previous',
#  u'che operi',
#  u'fare affari',
#  u'dispute about',
#  u'di valutazion.',
#  u'molto bene',
#  u'powers ,',
#  u'della polizia',
#  u'citoyens de',
#  u'that committee',
#  u'8 obligatoires',
#  u'fear from',
#  u'soumise au',
#  u'pouvons qu',
#  u'practical monitoring',
#  u'be issued',
#  u'Forests play',
#  u'satisfaire aux',
#  u'report back',
#  u'rilascio di',
#  u'job after',
#  u'de pays',
#  u'and minutes',
#  u'par eux',
#  u'Ad ogni',
#  u'\xe9t\xe9 accord\xe9',
#  u'avril 2000,',
#  u'includes various',
#  u'urgences .',
#  u'urgences ,',
#  u'distribution grid',
#  u'protesta di',
#  u'considerable financial',
#  u'cattiva amministrazione',
#  u'sociales elles',
#  u'interinstitutional agreement',
#  u'analyse des',
#  u'da concedere',
#  u'un parlamento',
#  u'cinesi in',
#  u'delle risultanze',
#  u'who gained',
#  u'Euro -',
#  u'condamn\xe9 .',
#  u'regional aid',
#  u'levels and',
#  u"Commission 's",
#  u'those suffering',
#  u'questa crisi',
#  u'Et il',
#  u'priv\xe9e qui',
#  u'sp\xe9cifiques des',
#  u'que l\xe0',
#  u'evidenziando gli',
#  u'lo sviluppo',
#  u'York ,',
#  u'rendicontazione pubblica',
#  u'B et',
#  u'legittimeranno l',
#  u'nourriture "',
#  u'nourriture ,',
#  u'be sought',
#  u'nourriture .',
#  u'di discarico',
#  u'prestation de',
#  u'taken by',
#  u'pr\xe9occupation exclusive',
#  u'avanzano obiezioni',
#  u'uomini che',
#  u'modo se',
#  u'una cittadinanza',
#  u'assai meglio',
#  u'whether this',
#  u'and cats',
#  u'decision taken',
#  u'women workers',
#  u'nei porti',
#  u'sottolineare alcuni',
#  u'degr\xe9 de',
#  u'la presente',
#  u'decidano e',
#  u'Moluccas .',
#  u'policy that',
#  u'11 percento',
#  u'there which',
#  u'Pronk .',
#  u'endorses Amendments',
#  u'Pronk ,',
#  u'Human Rights',
#  u'si tratter\xe0',
#  u'da Duma',
#  u'ces p\xe9titions',
#  u'such time',
#  u'gestione aerea',
#  u'd\xe9put\xe9 qui',
#  u'pourrait accepter',
#  u'pilotaggio per',
#  u'pr\xe9avis s\xe9rieux',
#  u'make money',
#  u'more efficiently',
#  u'europ\xe9en comme',
#  u'quello di',
#  u'sont lev\xe9es',
#  u'ha definito',
#  u'il preuve',
#  u'devons emp\xeacher',
#  u'eu l',
#  u'pr\xe9occupons aussi',
#  u'd\xe9bats d',
#  u'communicated during',
#  u'accordi che',
#  u'myself how',
#  u'que le',
#  u'che urga',
#  u'too sanctimonious',
#  u'particular Texas',
#  u'public reporting',
#  u'donna e',
#  u'regolari ,',
#  u'obiezioni di',
#  u'services qu',
#  u'Europe that',
#  u'must urgently',
#  u'the Euro',
#  u'r\xe9cup\xe9ration de',
#  u'regularise 65',
#  u'al riconoscimento',
#  u'as damaging',
#  u'hantent la',
#  u'not miraculously',
#  u'condamn\xe9 \xe0',
#  u'les atteintes',
#  u'in her',
#  u'eu -',
#  u'besoins et',
#  u'question essentielle',
#  u'hardly wonder',
#  u'increasing reality',
#  u'istituzione ,',
#  u'comp\xe9tences importantes',
#  u'obtenir que',
#  u'In other',
#  u'ben orchestrato',
#  u'et r\xe9ussie',
#  u'38, souligne',
#  u"d '",
#  u'pagato negli',
#  u'asked about',
#  u'rencontr\xe9es par',
#  u'for associations',
#  u'la l\xe9gislation',
#  u'arr\xeater ici',
#  u'le sixi\xe8me',
#  u'un passage',
#  u'not refer',
#  u'desidero innanzitutto',
#  u'\xe0 obtenir',
#  u'e rimboschire',
#  u'deve levare',
#  u'rappresentante austriaco',
#  u'certaine nuance',
#  u'sempre contraddistinte',
#  u'sicuramente contrari',
#  u'inoltre non',
#  u'La s\xe9paration',
#  u'incluront -',
#  u'the three',
#  u'nei Balcani',
#  u'a French',
#  u'our British',
#  u'EUROPOL et',
#  u'internationale de',
#  u'House who',
#  u'turn now',
#  u'economy and',
#  u'tali problemi',
#  u'base its',
#  u'basic factor',
#  u'In my',
#  u'comme en',
#  u"' \xe9pargner",
#  u'dont vous',
#  u'ancora carente',
#  u'when Haider',
#  u'down specific',
#  u'offre concr\xe8tement',
#  u', dovremmo',
#  u'Dobbiamo ricordare',
#  u'aussi barbare',
#  u'infanzia ,',
#  u'derni\xe8re avec',
#  u'dans une',
#  u'framework of',
#  u'les constatations',
#  u'le 13.30.',
#  u'petition and',
#  u'solutions ,',
#  u'down unacceptable',
#  u'observateurs du',
#  u'Atkins \xe9voque',
#  u'contr\xf4les quant',
#  u'in collaboration',
#  u'dai campi',
#  u'ruolo da',
#  u', incidentally',
#  u'trasporto ,',
#  u'cela pourrait',
#  u'nos informations',
#  u'volta soprattutto',
#  u'certains rapports',
#  u'moi et',
#  u'pi\xf9 accettabile',
#  u'divenire pi\xf9',
#  u'interessato sarebbero',
#  u'inizialmente avevamo',
#  u'delicata ma',
#  u'constate qu',
#  u'economically profitable',
#  u'mind and',
#  u'October we',
#  u'solutions \xe0',
#  u'then they',
#  u'unwillingness to',
#  u'dis \xe9galement',
#  u'Stimiamo opportuno',
#  u'nous est',
#  u'been positive',
#  u'r\xe9voltants quant',
#  u'juridique qui',
#  u'a biased',
#  u'\xe9taient inconnues',
#  u'contraddizione in',
#  u'iniziativa xenofoba',
#  u'secolo .',
#  u'tens of',
#  u'destructrice d',
#  u'everywhere on',
#  u'resa pubblica',
#  u'niveau r\xe9gional',
#  u'cooperazione da',
#  u'faut donc',
#  u'ne va',
#  u'suis n\xe9anmoins',
#  u'disparit\xe0 regionali',
#  u'of euro',
#  u'scheme is',
#  u'liberal countries',
#  u'suggestions in',
#  u'valore vincolante',
#  u', contr\xf4le',
#  u'di democrazia',
#  u'plans .',
#  u'put 132',
#  u'be maintained',
#  u'works of',
#  u'18 mai',
#  u'fer dans',
#  u'kilos .',
#  u'applied on',
#  u'Parlamento sia',
#  u'relazione molto',
#  u'of speeding',
#  u'son potentiel',
#  u'dello stadio',
#  u'mettre sur',
#  u'v\xe9ritables monnaies',
#  u'\xe2\x89\xa4 Leurs',
#  u'wonder why',
#  u'only with',
#  u'We can',
#  u'refuser de',
#  u'of Justice',
#  u'ulteriori ricerche',
#  u'pas suffisant',
#  u'the different',
#  u'di formare',
#  u'the planning',
#  u'italiano .',
#  u', prevista',
#  u'votazione nel',
#  u'leur destination',
#  u'jugement final',
#  u'pollution control',
#  u'dettata pi\xf9',
#  u'istituzione e',
#  u'succede in',
#  u'ma purtroppo',
#  u'hope for',
#  u'la protezione',
#  u'85 fu',
#  u'real Parliament',
#  u'constitue l',
#  u'Conseil en',
#  u'totale di',
#  u'burden off',
#  u'a multi',
#  u'talks of',
#  u'talks on',
#  u'e dittatoriale',
#  u'venue sur',
#  u'the research',
#  u'and liberalisation',
#  u'completamente inedito',
#  u'aircraft in',
#  u'l\xe9gislation le',
#  u'children by',
#  u'progressivement une',
#  u'sauvage pour',
#  u'In questo',
#  u'ceci est',
#  u'is struggling',
#  u'Lama is',
#  u'riguardano diritti',
#  u'stampa sia',
#  u'In questa',
#  u'it bites',
#  u'generously .',
#  u'des trois',
#  u'Hooligans "',
#  u'uvre pour',
#  u'delle preoccupazioni',
#  u'europeo nella',
#  u'abusi di',
#  u'autonomy of',
#  u'by reminding',
#  u'Tutto ci\xf2',
#  u'suggest that',
#  u'natalit\xe0 nell',
#  u'hardly the',
#  u'notamment qualifi\xe9',
#  u'al miglioramento',
#  u'profitable dans',
#  u'Ces accusations',
#  u'thank all',
#  u'projet m\xeame',
#  u'onorevole Jackson',
#  u'mia riconoscenza',
#  u'Schweiz das',
#  u'bombing like',
#  u'long courrier',
#  u'che costituiscono',
#  u'I really',
#  u'States --',
#  u'ampi strati',
#  u'cause de',
#  u'qui donnent',
#  u'wrong for',
#  u'a wonderful',
#  u'pressure off',
#  u'secrecy is',
#  u', sun',
#  u'a viable',
#  u'europ\xe9ens soutient',
#  u'seduta in',
#  u'\xe9nerv\xe9s voire',
#  u'fiscalit\xe9 "',
#  u'am\xe9lior\xe9 dans',
#  u'd\xe9mocrates chr\xe9tiens',
#  u'fa\xe7on beaucoup',
#  u'niveau actuel',
#  u'has paid',
#  u'questo argomento',
#  u'questo obiettivo',
#  u'juridique et',
#  u'highlight this',
#  u'the High',
#  u'questo periodo',
#  u'qui s\xe9pare',
#  u'I also',
#  ...]

# %%
s1 = set([1,2,3])
s2 = set([2,76,4])
dir(s1)
# Out:
# ['__and__',
#  '__class__',
#  '__cmp__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
help(s1.difference)
# Out:
# Help on built-in function difference:
#
# difference(...)
#     Return the difference of two or more sets as a new set.
#
#     (i.e. all elements that are in this set but not the others.)

# %%
s1.difference(s2)
# Out:
# {1, 3}

# %%
def evaluate(predicted_values):
    'calculate the accuracy'
    workdir = get_workdir()
    #read the test solution
    sol_path = os.path.join(workdir, 'solution')
    groundtruth_values = np.loadtxt(os.path.join(sol_path, 'LangId.sol'), dtype='S', delimiter=' ', usecols=[-1])
    return (groundtruth_values == predicted_values).sum() / float(groundtruth_values.size)

# %%
workdir = get_workdir()
sol_path = os.path.join(workdir, 'solution')
groundtruth_values = np.loadtxt(os.path.join(sol_path, 'LangId.sol'), dtype='S', delimiter=' ', usecols=[-1])

# %%
groundtruth_values
# Out:
# array(['Italian', 'English', 'Italian', 'French', 'French', 'English',
#        'English', 'English', 'French', 'French', 'English', 'Italian',
#        'English', 'English', 'French', 'English', 'French', 'French',
#        'Italian', 'English', 'Italian', 'French', 'Italian', 'French',
#        'Italian', 'English', 'English', 'English', 'English', 'English',
#        'English', 'English', 'English', 'French', 'French', 'Italian',
#        'French', 'English', 'French', 'Italian', 'Italian', 'French',
#        'Italian', 'Italian', 'French', 'Italian', 'French', 'Italian',
#        'French', 'Italian', 'English', 'Italian', 'Italian', 'Italian',
#        'Italian', 'Italian', 'Italian', 'English', 'French', 'French',
#        'Italian', 'French', 'English', 'Italian', 'Italian', 'French',
#        'French', 'English', 'Italian', 'Italian', 'English', 'Italian',
#        'English', 'English', 'English', 'English', 'English', 'Italian',
#        'Italian', 'Italian', 'Italian', 'English', 'Italian', 'English',
#        'Italian', 'English', 'English', 'English', 'English', 'French',
#        'Italian', 'English', 'French', 'English', 'Italian', 'Italian',
#        'Italian', 'Italian', 'French', 'English', 'French', 'Italian',
#        'English', 'English', 'French', 'French', 'French', 'French',
#        'French', 'French', 'French', 'French', 'English', 'English',
#        'French', 'English', 'Italian', 'Italian', 'Italian', 'Italian',
#        'Italian', 'Italian', 'English', 'English', 'English', 'French',
#        'Italian', 'English', 'French', 'Italian', 'French', 'French',
#        'French', 'English', 'Italian', 'French', 'English', 'French',
#        'French', 'English', 'French', 'English', 'English', 'French',
#        'Italian', 'French', 'French', 'Italian', 'Italian', 'French',
#        'Italian', 'English', 'English', 'French', 'Italian', 'English',
#        'French', 'French', 'Italian', 'French', 'French', 'English',
#        'English', 'French', 'English', 'English', 'French', 'Italian',
#        'Italian', 'English', 'Italian', 'Italian', 'French', 'English',
#        'Italian', 'French', 'Italian', 'English', 'French', 'English',
#        'Italian', 'French', 'French', 'Italian', 'French', 'Italian',
#        'Italian', 'French', 'French', 'Italian', 'French', 'English',
#        'French', 'English', 'French', 'English', 'French', 'French',
#        'Italian', 'Italian', 'English', 'French', 'English', 'Italian',
#        'French', 'English', 'English', 'French', 'English', 'French',
#        'Italian', 'French', 'French', 'Italian', 'English', 'English',
#        'Italian', 'French', 'French', 'English', 'French', 'English',
#        'Italian', 'English', 'Italian', 'Italian', 'Italian', 'French',
#        'Italian', 'English', 'English', 'Italian', 'English', 'Italian',
#        'French', 'English', 'English', 'Italian', 'English', 'French',
#        'French', 'Italian', 'English', 'Italian', 'English', 'Italian',
#        'Italian', 'Italian', 'English', 'English', 'English', 'French',
#        'English', 'Italian', 'English', 'English', 'Italian', 'Italian',
#        'Italian', 'English', 'Italian', 'Italian', 'Italian', 'French',
#        'English', 'French', 'French', 'Italian', 'English', 'French',
#        'English', 'French', 'English', 'English', 'Italian', 'French',
#        'Italian', 'English', 'French', 'French', 'English', 'English',
#        'French', 'Italian', 'French', 'French', 'English', 'French',
#        'Italian', 'Italian', 'French', 'French', 'French', 'Italian',
#        'French', 'French', 'Italian', 'Italian', 'French', 'English'],
#       dtype='|S7')

# %%
predicted_values.size
# Out:
# 100
